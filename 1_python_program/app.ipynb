# %%
from datetime import datetime
name = "Vitaliy"
location = "Kyiv"
print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Vitaliy start programming at 2025-12-14 23:08:52.906056. Kyiv is the best city!

# %%
message = "Привіт, світ! Я — Python."
print(message)
# Out:
# Привіт, світ! Я — Python.
